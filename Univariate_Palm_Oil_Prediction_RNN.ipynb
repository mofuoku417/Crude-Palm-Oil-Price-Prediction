# %% [markdown]
# <a href="https://colab.research.google.com/github/mofuoku417/Univariate_Crude_Palm_Oil_Price_Prediction/blob/main/Univariate_Palm_Oil_Prediction_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > **Predict Monthly Crude Palm Oil Price  with   Deep Learning (Recurrent Neural Network Univariate Time series)**
#
#
# > Project Objective:
#
# > Design and Build an RNN in tensorflow to predict Monthly Crude Palm Oil Price
#
#
#   * Data range: 1993 - 2022
#
#   The dataset is a CSV format with:
#
#   1. Monthly timestamp
#   2. Monthly Crude Palm Oil Prices
#
# ---------------------------------------------
#
#
# 1. Project Overview and Import Libraries
# 2. Load and Inspect Monthly Crude Oil Price History
# 1. Data Preprocessing
# 2. Build the RNN model
# 1. Train the RNN
# 2. Plot Metrics and Evaluate the Model
# 2. Monthly Crude Palm Oil Prices
# 2. Visualize the predictions

# %% [markdown]
# ###Load the Required Libraries

# %%
import math 
import numpy as np # Python's fundamental package for scientific computing
import pandas as pd # For data analysis and manipulation
from datetime import date, timedelta # Date Operations
import matplotlib.pyplot as plt # To aid in visualizing
import matplotlib.dates as mdates # Date formatting
from sklearn.metrics import mean_absolute_error, mean_squared_error # To assess model performance error computation
from sklearn.preprocessing import MinMaxScaler # to standardize the crude palm oil price data 
from tensorflow.keras.models import Sequential # Deep learning library, that is used in neural networks
from tensorflow.keras.layers import RNN, Dense # Deep learning classes for densely linked recurrent and regular layers
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from pandas import read_csv
import seaborn as sns
sns.set_style('white', { 'axes.spines.right': False, 'axes.spines.top': False})

# %%
# Establishing a timetable for data extraction
today = date.today()
end_date = today.strftime("%Y-%m")
start_date = '1993-03'

featurename = 'cpo_pri'


#Loading dataset
path = '/content/df_cl.csv'
df = read_csv(path, parse_dates=True)

# Examining the dataset's structure
print(df.shape)
df.head(5)
# Out:
# (361, 2)
#       date  cpo_pri
# 0  1993-03      408
# 1  1993-04      392
# 2  1993-05      371
# 3  1993-06      356
# 4  1993-07      362

# %%
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # Selecting only date
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head()
# Out:
#             cpo_pri
# date
# 1993-03-01      408
# 1993-04-01      392
# 1993-05-01      371
# 1993-06-01      356
# 1993-07-01      362

# %%
# Constructing a Lineplot
years = mdates.YearLocator() 
fig, ax1 = plt.subplots(figsize=(16, 6))
ax1.xaxis.set_major_locator(years)
ax1.legend([featurename], fontsize=12)
plt.title(featurename + ' from '+ start_date + ' to ' + end_date)
sns.lineplot(data=df['cpo_pri'], label=featurename, linewidth=1.0)
plt.ylabel('Monthly Crude Palm Oil Prices Per Metric Ton (US Dollars)')
plt.show()

# %%
# Target Selection 
train_df = df.filter(['cpo_pri'])
data_unsc = train_df.values # data_unscaled data

# Compute the number of rows required to train the model on 80% of the data. 
train_data_len = math.ceil(len(data_unsc) * 0.7)

# Scale each characteristic to a value between 0 and 1 to transform it.
mmscaler = MinMaxScaler(feature_range=(0, 1))
np_data = mmscaler.fit_transform(data_unsc)

# %%
# Set the sequence len - the period for making a single forecast.
sequence_len = 60

# Index of Prediction
index_cpo_pri = train_df.columns.get_loc("cpo_pri")
print(index_cpo_pri)
# Divide the training data into train and train data sets.
# In the first stage, we determine the number of rows required to train the model on 80% of the data. 
train_data_len = math.ceil(np_data.shape[0] * 0.8)

# Generate training and test data.
train_data = np_data[0:train_data_len, :]
test_data = np_data[train_data_len - sequence_len:, :]

# The RNN model requires data in the following formats: [samples, time steps, features].
def partition_dataset(sequence_len, train_df):
    x, y = [], []
    data_len = train_df.shape[0]
    for i in range(sequence_len, data_len):
        x.append(train_df[i-sequence_len:i,:]) 
        y.append(train_df[i, index_cpo_pri]) 
    
    # Convert the x and y variables to numpy arrays.
    x = np.array(x)
    y = np.array(y)
    return x, y

# Create training and testing data.
X_train, y_train = partition_dataset(sequence_len, train_data)
X_test, y_test = partition_dataset(sequence_len, test_data)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# Verify that the prediction value and the input value match
print(X_test[1][sequence_len-1][index_cpo_pri])
print(y_test[0])
# Out:
# 0
# (229, 60, 1) (229,)
# (72, 60, 1) (72,)
# 0.3357096565132858
# 0.3357096565132858

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

regressor = Sequential()

regressor.add(SimpleRNN(units = 100,activation='relu', return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))


regressor.add(SimpleRNN(units = 80,activation='relu', return_sequences = True))
regressor.add(Dropout(0.2))


regressor.add(SimpleRNN(units = 50,activation='relu', return_sequences = True))
regressor.add(Dropout(0.2))


regressor.add(SimpleRNN(units = 30,activation='relu', return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units = 20))
regressor.add(Dropout(0.2))


regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')


regressor.fit(X_train, y_train, epochs = 250, batch_size = 50)
# Out:
# Epoch 1/250
# 5/5 [==============================] - 7s 117ms/step - loss: 0.2035
# Epoch 2/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0643
# Epoch 3/250
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0385
# Epoch 4/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0248
# Epoch 5/250
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0251
# Epoch 6/250
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0241
# Epoch 7/250
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0190
# Epoch 8/250
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0163
# Epoch 9/250
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0151
# Epoch 10/250
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0148
# Epoch 11/250
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0164
# Epoch 12/250
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0160
# Epoch 13/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0145
# Epoch 14/250
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0129
# Epoch 15/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0156
# Epoch 16/250
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0123
# Epoch 17/250
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0116
# Epoch 18/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0133
# Epoch 19/250
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0127
# Epoch 20/250
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0129
# Epoch 21/250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0117
# Epoch 22/250
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0129
# Epoch 23/250
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0118
# Epoch 24/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0114
# Epoch 25/250
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0107
# Epoch 26/250
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0111
# Epoch 27/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0101
# Epoch 28/250
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0106
# Epoch 29/250
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0099
# Epoch 30/250
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0084
# Epoch 31/250
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0112
# Epoch 32/250
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0095
# Epoch 33/250
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0093
# Epoch 34/250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0107
# Epoch 35/250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0118
# Epoch 36/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0093
# Epoch 37/250
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0107
# Epoch 38/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0101
# Epoch 39/250
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0075
# Epoch 40/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0097
# Epoch 41/250
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0087
# Epoch 42/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0087
# Epoch 43/250
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0087
# Epoch 44/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0089
# Epoch 45/250
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0072
# Epoch 46/250
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0074
# Epoch 47/250
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0068
# Epoch 48/250
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0073
# Epoch 49/250
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0076
# Epoch 50/250
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0066
# Epoch 51/250
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0081
# Epoch 52/250
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0068
# Epoch 53/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0086
# Epoch 54/250
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0079
# Epoch 55/250
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0051
# Epoch 56/250
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0073
# Epoch 57/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0072
# Epoch 58/250
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0081
# Epoch 59/250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0069
# Epoch 60/250
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0068
# Epoch 61/250
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0053
# Epoch 62/250
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0077
# Epoch 63/250
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0051
# Epoch 64/250
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0057
# Epoch 65/250
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0059
# Epoch 66/250
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0063
# Epoch 67/250
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0059
# Epoch 68/250
# 5/5 [==============================] - 2s 337ms/step - loss: 0.0051
# Epoch 69/250
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0060
# Epoch 70/250
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0066
# Epoch 71/250
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0064
# Epoch 72/250
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0061
# Epoch 73/250
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0051
# Epoch 74/250
# 5/5 [==============================] - 1s 264ms/step - loss: 0.0051
# Epoch 75/250
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0052
# Epoch 76/250
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0055
# Epoch 77/250
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0047
# Epoch 78/250
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0050
# Epoch 79/250
# 5/5 [==============================] - 3s 617ms/step - loss: 0.0050
# Epoch 80/250
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0047
# Epoch 81/250
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0056
# Epoch 82/250
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0057
# Epoch 83/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0053
# Epoch 84/250
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0053
# Epoch 85/250
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0060
# Epoch 86/250
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0055
# Epoch 87/250
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0053
# Epoch 88/250
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0067
# Epoch 89/250
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0051
# Epoch 90/250
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0052
# Epoch 91/250
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0055
# Epoch 92/250
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0056
# Epoch 93/250
# 5/5 [==============================] - 1s 294ms/step - loss: 0.0065
# Epoch 94/250
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0049
# Epoch 95/250
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0050
# Epoch 96/250
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0050
# Epoch 97/250
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0051
# Epoch 98/250
# 5/5 [==============================] - 1s 304ms/step - loss: 0.0055
# Epoch 99/250
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0041
# Epoch 100/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0047
# Epoch 101/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0054
# Epoch 102/250
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0040
# Epoch 103/250
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0039
# Epoch 104/250
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0064
# Epoch 105/250
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0048
# Epoch 106/250
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0046
# Epoch 107/250
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0050
# Epoch 108/250
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0042
# Epoch 109/250
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0049
# Epoch 110/250
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0048
# Epoch 111/250
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0045
# Epoch 112/250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0043
# Epoch 113/250
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0049
# Epoch 114/250
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0047
# Epoch 115/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0056
# Epoch 116/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0037
# Epoch 117/250
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0046
# Epoch 118/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0046
# Epoch 119/250
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0045
# Epoch 120/250
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0049
# Epoch 121/250
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0047
# Epoch 122/250
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0050
# Epoch 123/250
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0044
# Epoch 124/250
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0039
# Epoch 125/250
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0042
# Epoch 126/250
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0034
# Epoch 127/250
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0056
# Epoch 128/250
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0039
# Epoch 129/250
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0045
# Epoch 130/250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0036
# Epoch 131/250
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0042
# Epoch 132/250
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0040
# Epoch 133/250
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0041
# Epoch 134/250
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0043
# Epoch 135/250
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0041
# Epoch 136/250
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0036
# Epoch 137/250
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0052
# Epoch 138/250
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0040
# Epoch 139/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0042
# Epoch 140/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0043
# Epoch 141/250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0034
# Epoch 142/250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0037
# Epoch 143/250
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0039
# Epoch 144/250
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0047
# Epoch 145/250
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0041
# Epoch 146/250
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0043
# Epoch 147/250
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0051
# Epoch 148/250
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0045
# Epoch 149/250
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0036
# Epoch 150/250
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0034
# Epoch 151/250
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0040
# Epoch 152/250
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0032
# Epoch 153/250
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0032
# Epoch 154/250
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0040
# Epoch 155/250
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0043
# Epoch 156/250
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0042
# Epoch 157/250
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0054
# Epoch 158/250
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0056
# Epoch 159/250
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0042
# Epoch 160/250
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0051
# Epoch 161/250
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0035
# Epoch 162/250
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0050
# Epoch 163/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0031
# Epoch 164/250
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0033
# Epoch 165/250
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0035
# Epoch 166/250
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0038
# Epoch 167/250
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0040
# Epoch 168/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0038
# Epoch 169/250
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0042
# Epoch 170/250
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0041
# Epoch 171/250
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0038
# Epoch 172/250
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0032
# Epoch 173/250
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0042
# Epoch 174/250
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0033
# Epoch 175/250
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0031
# Epoch 176/250
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0031
# Epoch 177/250
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0035
# Epoch 178/250
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0031
# Epoch 179/250
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0029
# Epoch 180/250
# 5/5 [==============================] - 1s 132ms/step - loss: 0.0030
# Epoch 181/250
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0030
# Epoch 182/250
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0031
# Epoch 183/250
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0031
# Epoch 184/250
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0040
# Epoch 185/250
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0035
# Epoch 186/250
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0037
# Epoch 187/250
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0031
# Epoch 188/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0038
# Epoch 189/250
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0035
# Epoch 190/250
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0034
# Epoch 191/250
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0031
# Epoch 192/250
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0030
# Epoch 193/250
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0033
# Epoch 194/250
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0033
# Epoch 195/250
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0029
# Epoch 196/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0041
# Epoch 197/250
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0038
# Epoch 198/250
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0028
# Epoch 199/250
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0029
# Epoch 200/250
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0030
# Epoch 201/250
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0028
# Epoch 202/250
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0030
# Epoch 203/250
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0031
# Epoch 204/250
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0026
# Epoch 205/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0034
# Epoch 206/250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0032
# Epoch 207/250
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0044
# Epoch 208/250
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0032
# Epoch 209/250
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0030
# Epoch 210/250
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0031
# Epoch 211/250
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0030
# Epoch 212/250
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0030
# Epoch 213/250
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0032
# Epoch 214/250
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0028
# Epoch 215/250
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0026
# Epoch 216/250
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0029
# Epoch 217/250
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0039
# Epoch 218/250
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0028
# Epoch 219/250
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0029
# Epoch 220/250
# 5/5 [==============================] - 1s 296ms/step - loss: 0.0025
# Epoch 221/250
# 5/5 [==============================] - 3s 500ms/step - loss: 0.0028
# Epoch 222/250
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0030
# Epoch 223/250
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0028
# Epoch 224/250
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0025
# Epoch 225/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0033
# Epoch 226/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0035
# Epoch 227/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0031
# Epoch 228/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0033
# Epoch 229/250
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0032
# Epoch 230/250
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0031
# Epoch 231/250
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0030
# Epoch 232/250
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0029
# Epoch 233/250
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0031
# Epoch 234/250
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0035
# Epoch 235/250
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0034
# Epoch 236/250
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0029
# Epoch 237/250
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0025
# Epoch 238/250
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0031
# Epoch 239/250
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0034
# Epoch 240/250
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0025
# Epoch 241/250
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0023
# Epoch 242/250
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0027
# Epoch 243/250
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0031
# Epoch 244/250
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0027
# Epoch 245/250
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0024
# Epoch 246/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0029
# Epoch 247/250
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0024
# Epoch 248/250
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0027
# Epoch 249/250
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0024
# Epoch 250/250
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0026

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = regressor.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=250,batch_size=50,verbose=1, callbacks=[callback])
# Out:
# Epoch 1/250
# 5/5 [==============================] - 2s 412ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 2/250
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0035 - val_loss: 0.0048
# Epoch 3/250
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 4/250
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 5/250
# 5/5 [==============================] - 2s 430ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 6/250
# 5/5 [==============================] - 2s 344ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 7/250
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 8/250
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 9/250
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 10/250
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 11/250
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 12/250
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 13/250
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 14/250
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 15/250
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 16/250
# 5/5 [==============================] - 2s 479ms/step - loss: 0.0020 - val_loss: 0.0030

# %%
'''
# Set up the neural network model


RNN_model = Sequential()

neurons = sequence_len

RNN_model.add(RNN(neurons, return_sequences=True, input_shape=(X_train.shape[1], 1))) 
RNN_model.add(RNN(neurons, return_sequences=False))
RNN_model.add(Dense(25, activation='relu'))
RNN_model.add(Dense(1))

# Compile the model
RNN_model.compile(optimizer='adam', loss='mean_squared_error')
'''

# %%
plt.figure(figsize=(6, 4))
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Test")
plt.title("Loss over epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Obtain the predicted values
RNN_pred_scaled = regressor.predict(X_test)
RNN_pred = mmscaler.inverse_transform(RNN_pred_scaled)
y_test_unsc = mmscaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 3/3 [==============================] - 0s 22ms/step

# %%
# Mean Absolute Error (MAE)
RNN_MAE = mean_absolute_error(y_test_unsc, RNN_pred)
print(f'Median Absolute Error (MAE): {np.round(RNN_MAE, 2)}')

# Mean Absolute Percentage Error (MAPE)
RNN_MAPE = np.mean((np.abs(np.subtract(y_test_unsc, RNN_pred)/ y_test_unsc))) * 100
print(f'Mean Absolute Percentage Error (MAPE): {np.round(RNN_MAPE, 2)} %')

# Root Mean Squared Error (RMSE)
RNN_RMSE = mean_squared_error(y_test_unsc, RNN_pred) ** 0.5
print(f'Root Mean Squared Error (RMSE): {np.round(RNN_RMSE, 2)} %')

# Mean Squared Error (MSE)
RNN_MSE = mean_squared_error(y_test_unsc, RNN_pred)
print('MSE value of the RNN Model:', RNN_MSE )

# r2_score
RNN_r2 = r2_score(y_test_unsc, RNN_pred)
print(f'R^2 Score: {np.round(RNN_r2, 2)} %')
# Out:
# Median Absolute Error (MAE): 56.57
# Mean Absolute Percentage Error (MAPE): 6.25 %
# Root Mean Squared Error (RMSE): 84.12 %
# MSE value of the RNN Model: 7076.197139845231
# R^2 Score: 0.92 %

# %%
train = pd.DataFrame(train_df[:train_data_len + 1]).rename(columns={'cpo_pri': 'X_train'})
train
# Out:
#             X_train
# date
# 1993-03-01      408
# 1993-04-01      392
# 1993-05-01      371
# 1993-06-01      356
# 1993-07-01      362
# ...             ...
# 2016-12-01      811
# 2017-01-01      825
# 2017-02-01      809
# 2017-03-01      779
# 2017-04-01      752
#
# [290 rows x 1 columns]

# %%
# The date from which on the date is displayed
display_start_date = "2010-12" 

# Add the difference between the valid and predicted prices
train = pd.DataFrame(train_df[:train_data_len + 1]).rename(columns={'cpo_pri': 'y_train'})
valid = pd.DataFrame(train_df[train_data_len:]).rename(columns={'cpo_pri': 'y_test'})
valid.insert(1, "RNN_pred", RNN_pred, True)
valid.insert(1, "residuals", valid["RNN_pred"] - valid["y_test"], True)
df_union = pd.concat([train, valid])

# Zoom in to a closer timeframe
df_union_zoom = df_union[df_union.index > display_start_date]

# Create the lineplot
fig, ax1 = plt.subplots(figsize=(16, 8), sharex=True)
plt.title("RNN Predictions vs Actual")
sns.set_palette(["#090364", "#1960EF", "#EF5919"])
plt.ylabel(featurename, fontsize=18)
sns.lineplot(data=df_union_zoom[['y_train', 'RNN_pred', 'y_test']], linewidth=1.0, dashes=False, ax=ax1)
# Out:
# <Axes: title={'center': 'RNN Predictions vs Actual'}, xlabel='date', ylabel='cpo_pri'>
